# %% [markdown]
# <a href="https://colab.research.google.com/github/mowreee/googol-colab/blob/main/PythonLists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Using Square Brackets
a = [1, 2, 3, 4, 5] # List of integers
b = ['apple', 'banana', 'cherry'] # List of strings
c = [1, 'hello', 3.14, True] # Mixed data types

print(a)
print(b)
print(c)
# Out:
# [1, 2, 3, 4, 5]
# ['apple', 'banana', 'cherry']
# [1, 'hello', 3.14, True]

# %%
#Using list() Constructor
a = list((1, 2, 3, 'apple', 4.5))
print(a)

b = list("GFG")
print(b)
# Out:
# [1, 2, 3, 'apple', 4.5]
# ['G', 'F', 'G']

# %%
#Creating List with Repeated Elements
a = [2] * 5
b = [0] * 7

print(a)
print(b)
# Out:
# [2, 2, 2, 2, 2]
# [0, 0, 0, 0, 0, 0, 0]

# %%
#Accessing List Elements
a = [10, 20, 30, 40, 50]
print(a[0])
print(a[-1])
print(a[1:4])   # elements from index 1 to 3
# Out:
# 10
# 50
# [20, 30, 40]

# %%
#Adding Elements into List
a = []

a.append(10)
print("After append(10):", a)

a.insert(0, 5)
print("After insert(0, 5):", a)

a.extend([15, 20, 25])
print("After extend([15, 20, 25]):", a)

a.clear()
print("After clear():", a)
# Out:
# After append(10): [10]
# After insert(0, 5): [5, 10]
# After extend([15, 20, 25]): [5, 10, 15, 20, 25]
# After clear(): []

# %%
#Updating Elemens into Lists
a = [10, 20, 30, 40, 50]
a[1] = 25
print(a)
# Out:
# [10, 25, 30, 40, 50]

# %%
#Removing Elements from List
a = [10, 20, 30, 40, 50]

a.remove(30)
print("After remove(30):", a)

popped_val = a.pop(1)
print("Popped element:", popped_val)
print("After pop(1):", a)

del a[0]
print("After del a[0]:", a)
# Out:
# After remove(30): [10, 20, 40, 50]
# Popped element: 20
# After pop(1): [10, 40, 50]
# After del a[0]: [40, 50]

# %%
#Iterating Over Lists
a = ['apple', 'banana', 'cherry']
for item in a:
    print(item)
# Out:
# apple
# banana
# cherry

# %%
#Nested Lists
matrix = [ [1, 2, 3],
           [4, 5, 6],
           [7, 8, 9] ]
print(matrix[1][2])
# Out:
# 6

# %%
#List Comprehension
squares = [x**2 for x in range(1, 6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]
