# %% [markdown]
# <a href="https://colab.research.google.com/github/mowreee/googol-colab/blob/main/Exam_Delos-Santos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def pas(num):
    for i in range(num1):
        print(" " * (num - i - 1), end = '')
        N = 1
        for col in range(i + 1):
            print(N, end = ' ')
            N = N * (i - col) // (col + 1)
        print()

while True:
    num1 = int(input("Enter N: "))
    if num1 < 0:
        print("N should be a positive integer")
    else:
        pas(num1)

    choice = input("Do you want to try again? (y/n): ").lower()

    if choice == 'n':
        print("Program closed...")
        break
    elif choice != 'y':
        print("Invalid input. Exiting.")
        break
